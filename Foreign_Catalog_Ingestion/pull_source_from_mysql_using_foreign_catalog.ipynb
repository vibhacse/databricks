# %%
print(dbutils.secrets.get("dbscope1","mysqlpassword1"))

# %%
# %sql
create connection mysql_new_connection2
  type mysql
  options(
    host "34.123.166.158",
    port "3306",
    user "devuser",
    password secret("dbscope1", "mysqlpassword1") --"Inceptez@123" password is derived from key defined in secret scope "dbscope1"
  );

# %%
# %sql
create foreign catalog if not exists mysql_foreign_cat
using connection mysql_new_connection2;

# %%
# %sql
describe connection mysql_new_connection2;
--show catalogs;

# %%
# %sql
select * from mysql_foreign_cat.logistics.shipments1;
