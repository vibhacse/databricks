# %%
# %sql
create connection mysql_new_connection1
type mysql
options(
  host "34.123.166.158",
  port "3306",
  user "devuser",
  password "Inceptez@123"
);

# %%
# %sql
create foreign catalog if not exists mysql_foreign_cat
using connection mysql_new_connection1;

# %%
# %sql
describe connection mysql_new_connection1;
show catalogs;

# %%
# %sql
select * from mysql_foreign_cat.logistics.shipments1;
