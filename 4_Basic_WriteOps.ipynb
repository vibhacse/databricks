# %%
sample_df=spark.read.csv(path="/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs_header",header=True,inferSchema=True)
write_df=sample_df.write.csv(path="/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/target1/custs_header",header=True,mode="Overwrite",sep="~")

# %%
transformed_df=sample_df.select("custid","fname","lname","age","profession").withColumnRenamed("profession","job")
#write_df=transformed_df.write.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/target1/custs_header/",header=True,mode="Overwrite",compression="gzip")
write_df=transformed_df.write.json("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/target1/custs_header/",mode="Overwrite")
