# %% [markdown]
# # Learn Databricks PySpark SQL
# It is built on an open-source foundation, using Apache Spark as its core technology, and is designed to combine the best features of data lakes and data warehouses in a lakehouse architecture.<br>
# ## **Good Day!** <br>
# $${\color{red}Vivekananda Bharathi}$$
# ### **Belongs to WD36 Batch** <br>
# #### **IN**<br>
# ![](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)<br>
# $${\color{green}Chennai}$$

# %%
# %sh
ls /databricks-datasets/airlines

# %%
# %sql
create volume if not exists workspace.default.usage_metrics

# %%
# %run
/Workspace/Users/vibhacse@gmail.com/databricks/4_child_nb_dataload

# %%
# %sql
select * from default.hollywood limit 10

# %%
def return_in_uppercase(name):
    return name.upper()

name=input("Enter your name:")
print(return_in_uppercase(name))

# %%
import pandas as pd
from io import StringIO

panda_df = pd.read_csv(StringIO(txtFile))
panda_df.display()

# %%
# %sh
echo 'The Magic Command Excersise Completed!'
