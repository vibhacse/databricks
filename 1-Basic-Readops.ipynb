# %%
# %sql
create catalog if not exists catalog1_dropme;
create database if not exists catalog1_dropme.schema1_dropme;
create volume if not exists catalog1_dropme.schema1_dropme.volume1_dropme;

# %%
# %python
dbutils.fs.mkdirs("dbfs:/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme")

# %%
#Create spark session object - On creating notebook by default spark session object will get created
#import pyspark.sql as SparkSession - Not recommended in databricks
print(spark)#default spark session object
#spark1=SparkSession.builder.getOrCreate()
#print(spark1)#user created spark session object, but still same instance returned

# %%
'''
df=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/patients.csv")
df.printSchema() #To print the structure
df.show()
'''
print("show csv with header=True to make 1st row as Column Name")
df1=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/patients.csv",header=True)
display(df1)
df1.printSchema()
print("To print schema with the actual data type instead of default dataype 'String'")
df3=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/patients.csv",header=True,inferSchema=True)
df3.printSchema()

# %%
#first row dont have header in the file, hence toDF to add meaningful column name instead of default column name such as c0,c1,c2 so on
df2=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/patients_withoutheader.csv").toDF("patientid","gender","SeniorCitizen","Married","Dependents","drugid","InPatient","Multipleillness","PaymentMethod","DrugCharges","TotalCharges")
display(df2.limit(10))

# %%
#Apply filter using SQL in the above dataset
#df2.filter("gender='Male'").show()
display(df2.filter("gender='Male'"))

# %%
#delimiters
df4=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs_~",sep="~").toDF("custid","fname","lname","age","occupation")
display(df4)
